# %% [markdown]
# <a href="https://colab.research.google.com/github/richwrather/data612/blob/main/DATA612_Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Name: Richard Wrather**
# ###**Assignment 4**

# %% [markdown]
# ## Action Items:
# •	Merge other data to your selected data set.
# 1. Find another data set, series, text data or a column from another data source and merge with your selected data set.
# 2. Identify the missing values on your data set. Count the missing values on your data set and then clean your data set from the missing values.
# 3. Post your work on GitHub
# 4. Add a README

# %%
import pandas as pd

# Read in the stocks_yahoo.csv dataset from the Franklin GitHub repo.
df = pd.read_csv("https://raw.githubusercontent.com/frankData612/data_612/master/stock_data/stocks_yahoo.csv")

# Manually create a new data frame to be added to the original 
new_row_df = pd.DataFrame([[df.shape[0] + 1, 'Jun 13 2021', 'AAPL - Apple Inc.', 
                            '129.64', '-0.30 (-0.23%)', '130.01', '129.94', '129.87', '129.64 - 131.32', 
                            '119.02 - 141.56', '2.876813+07', '25813040', '1.178T', '1.25', '22.08', '11.93', 'NaN', '3.08 (1.16%)', '259.12']],
                columns=['no', 'date', 'company_name', 'price_at_close', 'price_change',
                         'price_after_hours', 'previous_close', 'today opened', 'price range',
                         '52 week range', 'volume', 'average volume', 'market cap',
                         'beta (3Y Monthly)', 'PE Ratio', 'EPS', 'earnings date',
                         'Dividend Yield', '1Y target est'])

# Concatenate the two data frames and ignore the index
new_df = pd.concat([df, new_row_df], ignore_index=True)
new_df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           no         date  ... Dividend Yield 1Y target est
# 0          1  Nov 21 2019  ...      N/A (N/A)       1487.52
# 1          2  Nov 21 2019  ...      N/A (N/A)       1459.33
# 2          3  Nov 21 2019  ...   6.48 (4.86%)         148.3
# 3          4  Nov 21 2019  ...   2.04 (1.36%)        160.16
# 4          5  Nov 21 2019  ...   3.08 (1.16%)        257.21
# ...      ...          ...  ...            ...           ...
# 67901  67902  Apr 28 2020  ...   0.44 (1.49%)         33.33
# 67902  67903  Apr 28 2020  ...      N/A (N/A)          11.5
# 67903  67904  Apr 28 2020  ...      N/A (N/A)         67.67
# 67904  67905  Apr 28 2020  ...      N/A (N/A)         67.62
# 67905  67906  Jun 13 2021  ...   3.08 (1.16%)        259.12
#
# ...

# %%
# count the number of non-missing values
print(new_df.count())
# Out:
# no                   67906
# date                 67906
# company_name         67906
# price_at_close       67762
# price_change         67762
# price_after_hours    67762
# previous_close       67762
# today opened         67751
# price range          67757
# 52 week range        67658
# volume               67753
# average volume       66585
# market cap           67299
# beta (3Y Monthly)    63164
# PE Ratio             60221
# EPS                  64963
# earnings date        57612
# Dividend Yield       67626
# 1Y target est        57932
# dtype: int64

# %%
# Count the number of rows
num_rows = new_df.shape[0]

# Compute the number of missing rows
num_missing = num_rows - new_df.count()
print(num_missing)
# Out:
# no                       0
# date                     0
# company_name             0
# price_at_close         144
# price_change           144
# price_after_hours      144
# previous_close         144
# today opened           155
# price range            149
# 52 week range          248
# volume                 153
# average volume        1321
# market cap             607
# beta (3Y Monthly)     4742
# PE Ratio              7685
# EPS                   2943
# earnings date        10294
# Dividend Yield         280
# 1Y target est         9974
# dtype: int64

# %%
# Drop the rows with missing values
new_df_dropna = new_df.dropna()
new_df_dropna
# Out:
#           no         date  ... Dividend Yield 1Y target est
# 1          2  Nov 21 2019  ...      N/A (N/A)       1459.33
# 2          3  Nov 21 2019  ...   6.48 (4.86%)         148.3
# 3          4  Nov 21 2019  ...   2.04 (1.36%)        160.16
# 4          5  Nov 21 2019  ...   3.08 (1.16%)        257.21
# 5          6  Nov 21 2019  ...      N/A (N/A)       2183.86
# ...      ...          ...  ...            ...           ...
# 67899  67900  Apr 28 2020  ...      N/A (N/A)         66.75
# 67901  67902  Apr 28 2020  ...   0.44 (1.49%)         33.33
# 67902  67903  Apr 28 2020  ...      N/A (N/A)          11.5
# 67903  67904  Apr 28 2020  ...      N/A (N/A)         67.67
# 67905  67906  Jun 13 2021  ...   3.08 (1.16%)        259.12
#
# [47922 rows x 19 columns]
